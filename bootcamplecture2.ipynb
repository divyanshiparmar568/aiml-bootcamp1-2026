# %% [markdown]
# <a href="https://colab.research.google.com/github/divyanshiparmar568/aiml-bootcamp1-2026/blob/main/bootcamplecture2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name="riya"
marks=85
attendence=82.5
passed=True

print(name)
print(marks)
print(attendence)
print(passed)
# Out:
# riya
# 85
# 82.5
# True

# %%
x="10"
y="5"
print(x+y)
# Out:
# 105

# %%
mark1=75
marks=85
mark3=92

marks=[78,85,91]
marks.append(95)
print(len(marks))
print(max(marks))
print(min(marks))
# Out:
# 4
# 95
# 78

# %%
subjects = ["Python", "Math", "AI", "Data"]
print(subjects)
print(subjects[0])
print(subjects[-1])
# Out:
# ['Python', 'Math', 'AI', 'Data']
# Python
# Data

# %%
student=["ayush",88,True]
student={
    "name":"ayush",
    "mark":88,
    "enrolled":True
}
print(student["name"])
# Out:
# ayush

# %%
college={
    "Cname":"GLA UNIVERSITY",
    "Cclass":"CA"
}
college["City"] = "Mathura"
print(college)
# Out:
# {'Cname': 'GLA UNIVERSITY', 'Cclass': 'CA', 'City': 'Mathura'}

# %%
college={
    "name":"divya singh",
    "college_name":"GLA UNIVERSITY",
    "section":"CA",
    "grades":'A+',
    "city":"Mathura"
}
info1={
    "name":"ruhi",
    "college_name":"GLA UNIVERSITY",
    "section":"CC",
    "grades":"A+",
    "city":"Mathura"
}
info2={
    "name":"prachi parmar",
    "college_name":"GLA UNIVERSITY",
    "section":"CB",
    "grades":"A+",
    "city":"Mathura"
}
if college.get("grades") == "A+":
    print(college.get("name"))

if info1.get("grades") == "A+":
    print(info1.get("name"))

if info2.get("grades") == "A+":
    print(info2.get("name"))
# Out:
# divya singh
# ruhi
# prachi parmar

# %%
marks = 72

if marks>=40:
  print("Pass")
else:
  print("Fail")

marks = 72

if marks>=80:
  print("distinction ")
elif marks>=42 and marks<80:
  print("pass")
else:
  print("Fail")
# Out:
# Pass
# pass

# %%
marks =72

if marks % 2 == 0:
    print("Even marks")
else:
    print("Odd marks")
# Out:
# Even marks

# %%
age=int(input())
if age<13:
  print("child")
elif age>=13 and age<=19:
  print("teenager")
else:
  print("adult")
# Out:
# 17
# teenager

# %%
students=[
    {"name":"riya","marks":76,"lab_assign":True},
    {"name":"divya","marks":87,"lab_assign":True},
    {"name":"kajal","marks":56,"lab_assign":False}
]
for student in students:
    print(student["name"], student["marks"])
passed = [s for s in students if s["marks"] >= 60]
print(passed)
print("lab_assign" in students[2])
students[2]["Lab assign"] = True
print(students[2])
students[0]["grade"] = "B+"
print(students[0])
print(students[1].keys())
print(students[1].values())
print(students[1].items())
# Out:
# riya 76
# divya 87
# kajal 56
# [{'name': 'riya', 'marks': 76, 'lab_assign': True}, {'name': 'divya', 'marks': 87, 'lab_assign': True}]
# True
# {'name': 'kajal', 'marks': 56, 'lab_assign': False, 'Lab assign': True}
# {'name': 'riya', 'marks': 76, 'lab_assign': True, 'grade': 'B+'}
# dict_keys(['name', 'marks', 'lab_assign'])
# dict_values(['divya', 87, True])
# dict_items([('name', 'divya'), ('marks', 87), ('lab_assign', True)])
